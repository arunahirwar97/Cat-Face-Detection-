# %%
# import libraries
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
# before cat image mask detect 
cat = cv2.imread('H:/data/Screenshot_2020-09-20-22-16-13-732_com.google.android.googlequicksearchbox.jpg')
plt.figure(figsize = (20,100))
plt.imshow(cat,'BrBG')
plt.show()

# %%
cattelCascade = cv2.CascadeClassifier("G:/anaconda/Lib/site-packages/cv2/data/haarcascade_frontalcatface.xml")
while True:
    img = cv2.imread('H:/data/Screenshot_2020-09-20-22-16-13-732_com.google.android.googlequicksearchbox.jpg')
    img = cv2.flip(img,2)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = cattelCascade.detectMultiScale(
        gray,     
        scaleFactor=1.2,
        minNeighbors=5,     
        minSize=(20, 20)
    )
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]  
    cv2.imshow('video',img)
    k = cv2.waitKey(30) & 0xff
    if k == 27: # press 'ESC' to quit
        break
cv2.destroyAllWindows()

# %%
# After cat mask detect image 
plt.figure(figsize = (20,100))
plt.imshow(img,'BrBG')
plt.show()
